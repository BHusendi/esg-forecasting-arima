# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 01 - Data Exploration\n",
    "\n",
    "Explore and visualize the raw ESG data"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "import sys\n",
    "import os\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "sys.path.insert(0, os.path.join(os.getcwd(), '..'))\n",
    "\n",
    "from src.data_generator import ESGDataGenerator\n",
    "from src.data_processor import DataProcessor\n",
    "\n",
    "sns.set_style('whitegrid')\n",
    "plt.rcParams['figure.figsize'] = (14, 8)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Generate Data"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Generate synthetic data\n",
    "generator = ESGDataGenerator(n_periods=36, missing_rate=0.15, seed=42)\n",
    "df = generator.generate()\n",
    "\n",
    "print(\"\\nDataset Overview:\")\n",
    "print(df.head(15))"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Missing Values Analysis"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Analyze missing values\n",
    "processor = DataProcessor(df)\n",
    "missing_info = processor.analyze_missing_values()\n",
    "\n",
    "# Visualize missing values\n",
    "fig, ax = plt.subplots(figsize=(12, 6))\n",
    "missing_counts = df[['Environmental', 'Social', 'Governance']].isnull().sum()\n",
    "missing_counts.plot(kind='bar', ax=ax, color=['#1f77b4', '#ff7f0e', '#2ca02c'])\n",
    "ax.set_title('Missing Values by Parameter', fontsize=14, fontweight='bold')\n",
    "ax.set_ylabel('Count', fontsize=12)\n",
    "ax.set_xlabel('Parameter', fontsize=12)\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Statistical Summary"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Get data quality report\n",
    "quality_report = processor.get_data_quality_report()\n",
    "\n",
    "# Display statistics\n",
    "print(\"\\nStatistical Summary:\")\n",
    "print(df[['Environmental', 'Social', 'Governance']].describe())"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Time Series Visualization"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Plot time series\n",
    "fig, axes = plt.subplots(3, 1, figsize=(14, 10))\n",
    "\n",
    "params = ['Environmental', 'Social', 'Governance']\n",
    "colors = ['#1f77b4', '#ff7f0e', '#2ca02c']\n",
    "\n",
    "for idx, (param, color) in enumerate(zip(params, colors)):\n",
    "    ax = axes[idx]\n",
    "    \n",
    "    # Plot data\n",
    "    ax.plot(df.index, df[param], marker='o', color=color, linewidth=2, markersize=5, label='Data')\n",
    "    \n",
    "    # Mark missing values\n",
    "    missing_idx = df[df[param].isnull()].index\n",
    "    if len(missing_idx) > 0:\n",
    "        ax.scatter(missing_idx, [df[param].mean()]*len(missing_idx), \n",
    "                  color='red', s=100, marker='x', label='Missing', zorder=5)\n",
    "    \n",
    "    ax.set_title(f'{param} Parameter', fontsize=12, fontweight='bold')\n",
    "    ax.set_ylabel('Score', fontsize=11)\n",
    "    ax.grid(True, alpha=0.3)\n",
    "    ax.legend()\n",
    "\n",
    "axes[-1].set_xlabel('Time Period', fontsize=11)\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.9.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# 01 - Data Exploration\n",
#       8     "\n",
#       9     "Explore and visualize the raw ESG data"
#      10    ]
#      11   },
#      12   {
#      13    "cell_type": "code",
# ---> 14    "execution_count": null,
#      15    "metadata": {},
#      16    "outputs": [],
#      17    "source": [
#      18     "import sys\n",
#      19     "import os\n",
#      20     "import pandas as pd\n",
#      21     "import numpy as np\n",
#      22     "import matplotlib.pyplot as plt\n",
#      23     "import seaborn as sns\n",
#      24     "\n",
#      25     "sys.path.insert(0, os.path.join(os.getcwd(), '..'))\n",
#      26     "\n",
#      27     "from src.data_generator import ESGDataGenerator\n",
#      28     "from src.data_processor import DataProcessor\n",
#      29     "\n",
#      30     "sns.set_style('whitegrid')\n",
#      31     "plt.rcParams['figure.figsize'] = (14, 8)"
#      32    ]
#      33   },
#      34   {
#      35    "cell_type": "markdown",
#      36    "metadata": {},
#      37    "source": [
#      38     "## Generate Data"
#      39    ]
#      40   },
#      41   {
#      42    "cell_type": "code",
#      43    "execution_count": null,
#      44    "metadata": {},
#      45    "outputs": [],
#      46    "source": [
#      47     "# Generate synthetic data\n",
#      48     "generator = ESGDataGenerator(n_periods=36, missing_rate=0.15, seed=42)\n",
#      49     "df = generator.generate()\n",
#      50     "\n",
#      51     "print(\"\\nDataset Overview:\")\n",
#      52     "print(df.head(15))"
#      53    ]
#      54   },
#      55   {
#      56    "cell_type": "markdown",
#      57    "metadata": {},
#      58    "source": [
#      59     "## Missing Values Analysis"
#      60    ]
#      61   },
#      62   {
#      63    "cell_type": "code",
#      64    "execution_count": null,
#      65    "metadata": {},
#      66    "outputs": [],
#      67    "source": [
#      68     "# Analyze missing values\n",
#      69     "processor = DataProcessor(df)\n",
#      70     "missing_info = processor.analyze_missing_values()\n",
#      71     "\n",
#      72     "# Visualize missing values\n",
#      73     "fig, ax = plt.subplots(figsize=(12, 6))\n",
#      74     "missing_counts = df[['Environmental', 'Social', 'Governance']].isnull().sum()\n",
#      75     "missing_counts.plot(kind='bar', ax=ax, color=['#1f77b4', '#ff7f0e', '#2ca02c'])\n",
#      76     "ax.set_title('Missing Values by Parameter', fontsize=14, fontweight='bold')\n",
#      77     "ax.set_ylabel('Count', fontsize=12)\n",
#      78     "ax.set_xlabel('Parameter', fontsize=12)\n",
#      79     "plt.tight_layout()\n",
#      80     "plt.show()"
#      81    ]
#      82   },
#      83   {
#      84    "cell_type": "markdown",
#      85    "metadata": {},
#      86    "source": [
#      87     "## Statistical Summary"
#      88    ]
#      89   },
#      90   {
#      91    "cell_type": "code",
#      92    "execution_count": null,
#      93    "metadata": {},
#      94    "outputs": [],
#      95    "source": [
#      96     "# Get data quality report\n",
#      97     "quality_report = processor.get_data_quality_report()\n",
#      98     "\n",
#      99     "# Display statistics\n",
#     100     "print(\"\\nStatistical Summary:\")\n",
#     101     "print(df[['Environmental', 'Social', 'Governance']].describe())"
#     102    ]
#     103   },
#     104   {
#     105    "cell_type": "markdown",
#     106    "metadata": {},
#     107    "source": [
#     108     "## Time Series Visualization"
#     109    ]
#     110   },
#     111   {
#     112    "cell_type": "code",
#     113    "execution_count": null,
#     114    "metadata": {},
#     115    "outputs": [],
#     116    "source": [
#     117     "# Plot time series\n",
#     118     "fig, axes = plt.subplots(3, 1, figsize=(14, 10))\n",
#     119     "\n",
#     120     "params = ['Environmental', 'Social', 'Governance']\n",
#     121     "colors = ['#1f77b4', '#ff7f0e', '#2ca02c']\n",
#     122     "\n",
#     123     "for idx, (param, color) in enumerate(zip(params, colors)):\n",
#     124     "    ax = axes[idx]\n",
#     125     "    \n",
#     126     "    # Plot data\n",
#     127     "    ax.plot(df.index, df[param], marker='o', color=color, linewidth=2, markersize=5, label='Data')\n",
#     128     "    \n",
#     129     "    # Mark missing values\n",
#     130     "    missing_idx = df[df[param].isnull()].index\n",
#     131     "    if len(missing_idx) > 0:\n",
#     132     "        ax.scatter(missing_idx, [df[param].mean()]*len(missing_idx), \n",
#     133     "                  color='red', s=100, marker='x', label='Missing', zorder=5)\n",
#     134     "    \n",
#     135     "    ax.set_title(f'{param} Parameter', fontsize=12, fontweight='bold')\n",
#     136     "    ax.set_ylabel('Score', fontsize=11)\n",
#     137     "    ax.grid(True, alpha=0.3)\n",
#     138     "    ax.legend()\n",
#     139     "\n",
#     140     "axes[-1].set_xlabel('Time Period', fontsize=11)\n",
#     141     "plt.tight_layout()\n",
#     142     "plt.show()"
#     143    ]
#     144   }
#     145  ],
#     146  "metadata": {
#     147   "kernelspec": {
#     148    "display_name": "Python 3",
#     149    "language": "python",
#     150    "name": "python3"
#     151   },
#     152   "language_info": {
#     153    "name": "python",
#     154    "version": "3.9.0"
#     155   }
#     156  },
#     157  "nbformat": 4,
#     158  "nbformat_minor": 4
#     159 }
#
# NameError: name 'null' is not defined
